# %% [markdown]
# # Parameter identification example
#
# Here is a simple toy model that we use to demonstrate the working of the inference package
#
# $\emptyset \xrightarrow[]{k_1} X \; \; \; \; X \xrightarrow[]{d_1} \emptyset$
#
# ### Run the MCMC algorithm to identify parameters from the experimental data

# %%
# %matplotlib inline
import bioscrape as bs
from bioscrape.types import Model
from bioscrape.simulator import py_simulate_model
from bioscrape.pid_interfaces import *
from bioscrape.emcee_interface import *
import numpy as np
import pylab as plt
import pandas as pd

pid = initialize_mcmc()
# Import bioscrape XML / bioscrape model object M / SBML file
# M  = bs.types.read_model_from_sbml(filename)
pid.M = Model('models/toy_model.xml')


# Import data from CSV
# Import a CSV file for each experiment run
pid.exp_data = pd.read_csv('test_data.csv', delimiter = '\t', names = ['X','time'], skiprows = 1)
# data_list.append(list(data.get('X')))
# pid.exp_data = np.array(data_list)
pid.measurements = ['X']
pid.time_column = ['time']
pid.prior = {'k1' : ['uniform', 10, 100, 1e-7],'d1' : ['gaussian', 0.2, 1, 1e-5]}
pid.params_to_estimate = ['k1', 'd1']
pid.nwalkers = 20

pid.init_seed = 0.15
pid.type = 'deterministic'


fitted_model, params = pid.run_mcmc(plot_show = True)
# Out:
# C:\Users\apand\AppData\Local\Continuum\anaconda3\lib\site-packages\emcee\moves\red_blue.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
# Successfully completed MCMC parameter identification procedure. Parameter distribution data written to mcmc_results.csv file
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-6af41f3e41eb> in <module>
#      29
#      30
# ---> 31 fitted_model, params = pid.run_mcmc(plot_show = True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bioscrape\emcee_interface.py in run_mcmc(self, **kwargs)
#      45             self.initial_conditions = self.M.get_species_dictionary()
#      46         self.prepare_mcmc(**kwargs)
# ---> 47         fitted_model, params = self.run_emcee(**kwargs)
#      48         return fitted_model.M, params
#      49
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bioscrape\emcee_interface.py in run_emcee(self, **kwargs)
#     220             f.close()
#     221         print('Successfully completed MCMC parameter identification procedure. Parameter distribution data written to mcmc_results.csv file')
# --> 222         fitted_model, params = self.plot_mcmc_results(sampler, plot_show)
#     223         return fitted_model, params
#     224
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bioscrape\emcee_interface.py in plot_mcmc_results(self, sampler, plot_show)
#     242             best_p_ind = np.where(n == np.max(n))
#     243             if np.shape(best_p_ind)[-1] != 1:
# --> 244                 warnings.warn('Multiple parameter values for {0} found with max distribution, choosing the first one. The results might be misleadig.'.format(params_names[i]))
#     245                 best_p_ind = np.array(best_p_ind[0].tolist()[0])
#     246             assert len(best_p_ind) == 1
#
# UnboundLocalError: local variable 'params_names' referenced before assignment

# %% [markdown]
# ### Check mcmc_results.csv for the results of the MCMC procedure and perform your own analysis.
#
# ### You can also plot the results as follows

# %%
timepoints = pid.timepoints
M_original = Model('models/toy_model.xml')
sim_x = py_simulate_model(timepoints, Model = M_original, stochastic = False)
sim_x_inf = py_simulate_model(timepoints, Model = fitted_model, stochastic = False)
plt.plot(timepoints, sim_x['X'], 'r--', label = 'Original model')
plt.plot(timepoints, pid.exp_data.get('X'), label = 'Experimental data')
plt.plot(timepoints, sim_x_inf['X'], 'k', label = 'Identified model')

plt.legend()

# %% [markdown]
# ## Alll methods above have other advanced options that you can use. Refer to Parameter Identification Tools and Advanced Examples notebook for more details. There are many other tools available such as for multiple initial conditions and timepoints for each trajectory, options for the estimator etc.

# %%
fitted_model.get_parameter_values()
# Out:
# array([0.20009729, 9.5081574 ])

# %%
pid.exp_data
# Out:
#             X       time
# 0   71.999673   4.000000
# 1   63.048092   4.918367
# 2   60.009484   5.836735
# 3   62.021921   6.755102
# 4   57.028625   7.673469
# 5   55.046796   8.591837
# 6   60.990691   9.510204
# 7   56.001016  10.428571
# 8   54.000635  11.346939
# 9   54.966352  12.265306
# 10  51.993488  13.183673
# 11  49.990286  14.102041
# 12  55.993366  15.020408
# 13  51.032324  15.938776
# 14  57.032121  16.857143
# 15  56.971458  17.775510
# 16  49.997691  18.693878
# 17  47.993838  19.612245
# 18  52.998608  20.530612
# 19  50.015374  21.448980
# 20  45.995280  22.367347
# 21  48.000328  23.285714
# 22  46.031771  24.204082
# 23  45.971498  25.122449
# 24  42.993963  26.040816
# 25  41.033018  26.959184
# 26  44.026727  27.877551
# 27  42.989539  28.795918
# 28  38.995624  29.714286
# 29  39.963221  30.632653
# 30  35.972735  31.551020
# 31  39.004238  32.469388
# 32  32.971275  33.387755
# 33  34.998297  34.306122
# 34  34.961044  35.224490
# 35  31.015458  36.142857
# 36  39.980352  37.061224
# 37  42.020535  37.979592
# 38  41.982646  38.897959
# 39  43.986500  39.816327
# 40  46.016603  40.734694
# 41  47.993715  41.653061
# 42  41.977985  42.571429
# 43  42.046719  43.489796
# 44  44.004508  44.408163
# 45  47.050001  45.326531
# 46  43.980594  46.244898
# 47  46.000443  47.163265
# 48  45.038858  48.081633
# 49  44.023118  49.000000
